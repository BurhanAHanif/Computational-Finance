# %% [markdown]
# ## This notebook will only work on the quantopian Platform and You will need your own unique backest-ID.

# %% [markdown]
# ## Leverage on Amazon and IBM Long-Short in application with/out Margin

# %% [markdown]
# # Code for Backtest on the IDE of Quantopian

# %%
def initialize(context):
    context.amzn = sid(16841)
    context.ibm = sid(3766)
    
    schedule_function(rebalance,date_rules.every_day(),time_rules.market_open())
    schedule_function(record_vars,date_rules.every_day(),time_rules.market_close())
    
def rebalance(context,data):
    order_target_percent(context.amzn,0.5)
    order_target_percent(context.ibm,-0.5)
    
def record_vars(context,data):
    record(amzn_close=data.current(context.amzn,'close'))
    record(ibm_close=data.current(context.ibm,'close'))
    record(Leverage = context.account.leverage)
    record(Exposure = context.account.net_leverage)

# %% [markdown]
# # After running the backtest you will have your own ID so insert

# %% [markdown]
# # Back-Test INFO

# %%
bt = get_backtest('5e8399a09b3e8a4576916d84')
# Out:
# 100% Time:  0:00:00|##########################################################|

# %%
bt.benchmark_security
# Out:
# 8554

# %%
bt.algo_id
# Out:
# '5e8399a09b3e8a4576916d84'

# %%
bt.recorded_vars
# Out:
#                            Exposure  Leverage  amzn_close  ibm_close
# 2019-01-02 00:00:00+00:00  0.011373  1.020649    1536.730    114.840
# 2019-01-03 00:00:00+00:00 -0.003231  0.990119    1502.070    113.140
# 2019-01-04 00:00:00+00:00  0.004128  1.022998    1574.540    117.280
# 2019-01-07 00:00:00+00:00  0.007154  1.007147    1631.120    118.230
# 2019-01-08 00:00:00+00:00 -0.001853  1.001474    1655.835    119.870
# 2019-01-09 00:00:00+00:00  0.003320  0.997767    1657.590    120.620
# 2019-01-10 00:00:00+00:00  0.000394  1.008316    1655.500    121.680
# 2019-01-11 00:00:00+00:00  0.000423  0.998408    1639.660    121.310
# 2019-01-14 00:00:00+00:00  0.005726  0.991862    1619.877    120.470
# 2019-01-15 00:00:00+00:00  0.009991  1.006323    1672.750    121.660
# 2019-01-16 00:00:00+00:00 -0.000971  1.000584    1681.970    121.600
# 2019-01-17 00:00:00+00:00 -0.002593  1.011298    1691.370    122.090
# 2019-01-18 00:00:00+00:00 -0.007272  1.005302    1693.242    123.760
# 2019-01-22 00:00:00+00:00 -0.008428  0.987464    1628.398    121.860
# 2019-01-23 00:00:00+00:00 -0.012354  1.015469    1636.550    132.860
# 2019-01-24 00:00:00+00:00  0.006080  0.999779    1654.970    132.550
# 2019-01-25 00:00:00+00:00 -0.003858  1.009080    1668.600    133.985
# 2019-01-28 00:00:00+00:00 -0.004057  1.006735    1636.185    134.303
# 2019-01-29 00:00:00+00:00 -0.011389  1.000860    1592.730    134.370
# 2019-01-30 00:00:00+00:00  0.012528  1.002910    1670.231    134.420
# 2019-01-31 00:00:00+00:00  0.008943  0.999816    1720.410    134.480
# 2019-02-01 00:00:00+00:00  0.000748  0.993035    1623.800    134.020
# 2019-02-04 00:00:00+00:00 -0.004479  1.009846    1630.500    135.110
# 2019-02-05 00:00:00+00:00  0.003840  0.999505    1656.870    135.330
# 2019-02-06 00:00:00+00:00 -0.013320  1.008132    1639.420    136.305
# 2019-02-07 00:00:00+00:00  0.000001  0.993514    1611.606    133.000
# 2019-02-08 00:00:00+00:00 -0.003404  1.007687    1585.740    133.515
# 2019-02-11 00:00:00+00:00 -0.001929  0.997481    1591.800    134.050
# 2019-02-12 00:00:00+00:00  0.007952  1.005657    1637.890    135.970
# 2019-02-13 00:00:00+00:00 -0.005502  1.005517    1640.373    137.550
# ...                             ...       ...         ...        ...
# 2019-11-18 00:00:00+00:00  0.003488  1.001257    1752.395    134.152
# 2019-11-19 00:00:00+00:00  0.000364  0.997889    1752.688    134.580
# 2019-11-20 00:00:00+00:00  0.004181  0.990232    1744.700    133.010
# 2019-11-21 00:00:00+00:00 -0.006039  1.005051    1734.260    133.810
# 2019-11-22 00:00:00+00:00  0.001661  1.000706    1745.790    134.289
# 2019-11-25 00:00:00+00:00 -0.001542  1.011693    1773.400    135.890
# 2019-11-26 00:00:00+00:00  0.007576  0.993174    1794.945    135.020
# 2019-11-27 00:00:00+00:00  0.011460  0.988624    1818.840    133.730
# 2019-11-29 00:00:00+00:00 -0.007588  1.005136    1802.130    134.280
# 2019-12-02 00:00:00+00:00 -0.001433  0.990041    1780.990    132.972
# 2019-12-03 00:00:00+00:00  0.001332  1.003846    1770.860    132.090
# 2019-12-04 00:00:00+00:00 -0.001278  0.993996    1761.190    132.140
# 2019-12-05 00:00:00+00:00 -0.001939  0.993099    1741.070    131.935
# 2019-12-06 00:00:00+00:00 -0.000744  1.002196    1752.240    133.259
# 2019-12-09 00:00:00+00:00 -0.001876  1.003815    1749.391    134.075
# 2019-12-10 00:00:00+00:00 -0.002458  0.999563    1738.730    133.930
# 2019-12-11 00:00:00+00:00  0.002668  0.999435    1749.728    133.757
# 2019-12-12 00:00:00+00:00 -0.002202  1.011785    1760.311    135.420
# 2019-12-13 00:00:00+00:00  0.003561  0.996386    1761.760    134.170
# 2019-12-16 00:00:00+00:00  0.005349  0.990953    1769.105    133.974
# 2019-12-17 00:00:00+00:00  0.004115  0.997864    1791.870    134.270
# 2019-12-18 00:00:00+00:00 -0.003359  1.000538    1784.230    134.530
# 2019-12-19 00:00:00+00:00  0.003105  0.999477    1791.700    134.450
# 2019-12-20 00:00:00+00:00 -0.003316  1.000601    1785.220    135.760
# 2019-12-23 00:00:00+00:00  0.003455  0.996048    1792.470    135.415
# 2019-12-24 00:00:00+00:00  0.000271  0.995849    1788.890    134.965
# 2019-12-26 00:00:00+00:00  0.018327  0.998993    1868.730    134.795
# 2019-12-27 00:00:00+00:00 -0.004016  1.001712    1869.915    135.240
# 2019-12-30 00:00:00+00:00  0.002198  0.980777    1845.510    132.510
# 2019-12-31 00:00:00+00:00 -0.002752  1.010673    1847.410    133.970
#
# [252 rows x 4 columns]

# %%
bt.recorded_vars['Leverage'].plot()

# %%
bt.recorded_vars['Exposure'].plot()

# %% [markdown]
# ## High Leverage 4x on margin

# %%
def initialize(context):
    context.amzn = sid(16841)
    context.ibm = sid(3766)
    
    schedule_function(rebalance,date_rules.every_day(),time_rules.market_open())
    schedule_function(record_vars,date_rules.every_day(),time_rules.market_close())
    
def rebalance(context,data):
    order_target_percent(context.amzn,2.0)
    order_target_percent(context.ibm,-2.0)
    
def record_vars(context,data):
    record(amzn_close=data.current(context.amzn,'close'))
    record(ibm_close=data.current(context.ibm,'close'))
    record(Leverage = context.account.leverage)
    record(Exposure = context.account.net_leverage)

# %%
bt = get_backtest('5e83a9cd8fd84a458cea88bc')
# Out:
# 100% Time:  0:00:00|##########################################################|

# %%
bt.recorded_vars['Leverage'].plot()

# %% [markdown]
# ## Set limit on High - Leverage

# %%
def initialize(context):
    context.amzn = sid(16841)
    context.ibm = sid(3766)
    # code for setting limit on Portfolio
    set_max_leverage(1.03)
    
    schedule_function(rebalance,date_rules.every_day(),time_rules.market_open())
    schedule_function(record_vars,date_rules.every_day(),time_rules.market_close())
    
def rebalance(context,data):
    order_target_percent(context.ibm,-0.5)
    order_target_percent(context.amzn,0.5)
    
def record_vars(context,data):
    record(amzn_close=data.current(context.amzn,'close'))
    record(ibm_close=data.current(context.ibm,'close'))
    record(Leverage = context.account.leverage)
    record(Exposure = context.account.net_leverage)
